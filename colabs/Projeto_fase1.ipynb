# %%
# !unzip projeto.zip
# Out:
# Archive:  projeto.zip
#    creating: datasets/
#   inflating: datasets/bambenek_dga_domain_30.csv
#   inflating: datasets/top-1m.csv
#    creating: dga_classifier/
#   inflating: dga_classifier/bigram.py
#   inflating: dga_classifier/data.py
#   inflating: dga_classifier/hmm.py
#   inflating: dga_classifier/lstm.py
#   inflating: dga_classifier/randomforest.py
#   inflating: dga_classifier/__init__.py
#   inflating: run.py

# %%
# !pip install hmmlearn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 kB 7.1 MB/s eta 0:00:00
# ...

# %%
# !python run.py
# Out:
# 2026-06-09 01:03:01.891790: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
# Experimento 1: Classificação Binária | nfolds=1 hmm=True
# ...
#
# === Bigrams ===
# [data] DGA path: datasets/bambenek_dga_domain_30.csv
# [data] Alexa path: datasets/top-1m.csv
# [data] DGA original: 828454
# [data] DGA usado: 81552 | max_per_family=5000 | max_dga=None
# [data] Benignos usados: 100000 | balance=False | max_benign=100000
# [data] Total: 181552
# [data] Top famílias DGA: [('cryptolocker', 5000), ('shiotob', 5000), ('ramnit', 5000), ('simda', 5000), ('qakbot', 5000), ('posttovargoz', 5000), ('ranbyus', 5000), ('tinba', 5000), ('nymaim', 5000), ('dyre', 5000)]
# vectorizing data
# fold 1/1
# Build model...
# ...

# %%
# !zip -r resultados_dga.zip *.pkl *.png
# Out:
#   adding: lco_results.pkl (deflated 32%)
#   adding: multi_results_familias.pkl (deflated 32%)
#   adding: multi_results_superfamilias.pkl (deflated 41%)
#   adding: results_binary.pkl (deflated 75%)
#   adding: results_roc.png (deflated 7%)
